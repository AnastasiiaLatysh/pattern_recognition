# %% [markdown]
# <a href="https://colab.research.google.com/github/AnastasiiaLatysh/pattern_recognition/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
from tensorflow.keras import datasets, layers, models
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.2.0'

# %%
K.image_data_format()
# Out:
# 'channels_last'

# %%
def plot_accouracy_training_history(history):
  plt.plot(history.history['acc'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train'], loc='upper left')
  plt.show()

# %%
def plot_accuracy_training_history_with_validation(history):
  plt.plot(history.history['acc'])
  plt.plot(history.history['val_acc'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

# %%
def plot_loss_training_history(history):
  plt.plot(history.history['loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train'], loc='upper left')
  plt.show()

# %%
def plot_loss_training_history_with_validation(history):
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 10
ncols = 10

# Index for iterating over images
pic_index = 0

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
plt.style.use('grayscale')
fig.set_size_inches(ncols, nrows)

images_to_show_count = nrows * ncols

pic_index += images_to_show_count
next_image_pix = [image for image in x_train[pic_index-images_to_show_count:pic_index, :, :]]

for i, img in enumerate(next_image_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  plt.imshow(img)

plt.show()

# %% [markdown]
# Виконуємо нормалізацію

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# Щоб переконатися, що набір даних виглядає правильним, давайте побудуємо перші 25 зображень із навчального набору та відобразимо ім’я класу під кожним зображенням.

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[y_train[i][0]])
plt.show()

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
def grayscale(data):
    # luma coding weighted average in video systems
    r, g, b = np.asarray(0.3, 'float32'), np.asarray(.59, 'float32'), np.asarray(.11, 'float32')
    rst = r * data[:, :, :, 0] + g * data[:, :, :, 1] + b * data[:, :, :, 2]
    # add channel dimension
    rst = np.expand_dims(rst, axis=3)
    return rst

# %%
x_train = grayscale(x_train)
x_test = grayscale(x_test)

# %%
basic_cnn = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, (3,3),  kernel_initializer='he_uniform', activation='relu', padding='same', input_shape=(32, 32, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Conv2D(64, (3,3),  kernel_initializer='he_uniform', activation='relu',  padding='same'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Conv2D(128, (3,3),  kernel_initializer='he_uniform', activation='relu', padding='same'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, kernel_initializer='he_uniform', activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10,  kernel_initializer='he_uniform', activation='softmax')
])

# %%
basic_cnn.compile(optimizer = tf.optimizers.Adam(learning_rate=0.001), loss = 'categorical_crossentropy', metrics=['accuracy'])
basic_cnn_history = basic_cnn.fit(x_test, y_train, epochs=1, validation_data=(x_test, y_test))
plot_loss_training_history_with_validation(basic_cnn_history)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-166-9be398ea47e5> in <module>()
#       1 basic_cnn.compile(optimizer = tf.optimizers.Adam(learning_rate=0.001), loss = 'categorical_crossentropy', metrics=['accuracy'])
# ----> 2 basic_cnn_history = basic_cnn.fit(x_test, y_train, epochs=1, validation_data=(x_test, y_test))
#       3 plot_loss_training_history_with_validation(basic_cnn_history)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ...

# %%
basic_cnn.compile(optimizer = tf.optimizers.Adam(learning_rate=0.001), loss = 'categorical_crossentropy', metrics=['accuracy'])
basic_cnn_history = basic_cnn.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test))
plot_loss_training_history_with_validation(basic_cnn_history)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-158-c190b58fe01f> in <module>()
#       1 basic_cnn.compile(optimizer = tf.optimizers.Adam(learning_rate=0.001), loss = 'categorical_crossentropy', metrics=['accuracy'])
# ----> 2 basic_cnn_history = basic_cnn.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test))
#       3 plot_loss_training_history_with_validation(basic_cnn_history)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ...

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_33 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 4, 4, 64)          36928
# ...
# Total params: 56,320
# Trainable params: 56,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dense(10))

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_33 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 4, 4, 64)          36928
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                65600
# ...

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, 
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.6914 - accuracy: 0.4147 - val_loss: 1.3532 - val_accuracy: 0.5157
# Epoch 2/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.2870 - accuracy: 0.5406 - val_loss: 1.2536 - val_accuracy: 0.5479
# Epoch 3/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.1440 - accuracy: 0.6005 - val_loss: 1.1247 - val_accuracy: 0.6085
# Epoch 4/10
# 1563/1563 [==============================] - 5s 4ms/step - loss: 1.0385 - accuracy: 0.6362 - val_loss: 1.1421 - val_accuracy: 0.6047
# Epoch 5/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.9610 - accuracy: 0.6658 - val_loss: 1.0734 - val_accuracy: 0.6327
# Epoch 6/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.8858 - accuracy: 0.6917 - val_loss: 1.1261 - val_accuracy: 0.6281
# Epoch 7/10
# ...

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(x_test,  y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0473 - accuracy: 0.6719

# %%
f, axarr = plt.subplots(3,4)
FIRST_IMAGE=0
SECOND_IMAGE=8
THIRD_IMAGE=32
CONVOLUTION_NUMBER = 10
layer_outputs = [layer.output for layer in model.layers]
activation_model = keras.models.Model(inputs = model.input, outputs = layer_outputs)
for x in range(0,4):
  f1 = activation_model.predict(x_test[FIRST_IMAGE].reshape(1, 32, 32, 1))[x]
  axarr[0,x].imshow(f1[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[0,x].grid(False)
  f2 = activation_model.predict(x_test_gray[SECOND_IMAGE].reshape(1, 32, 32, 1))[x]
  axarr[1,x].imshow(f2[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[1,x].grid(False)
  f3 = activation_model.predict(x_test_gray[THIRD_IMAGE].reshape(1, 32, 32, 1))[x]
  axarr[2,x].imshow(f3[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[2,x].grid(False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-7bbce6b0ec96> in <module>()
#       7 activation_model = keras.models.Model(inputs = model.input, outputs = layer_outputs)
#       8 for x in range(0,4):
# ----> 9   f1 = activation_model.predict(x_test[FIRST_IMAGE].reshape(1, 32, 32, 1))[x]
#      10   axarr[0,x].imshow(f1[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
#      11   axarr[0,x].grid(False)
#
# ValueError: cannot reshape array of size 3072 into shape (1,32,32,1)
